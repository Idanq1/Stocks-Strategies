# %%
import pandas as pd

# %%
df = pd.read_csv(r"google sheets .csv").drop([0,1,2,3])[["Field Value", "Unnamed: 5"]]
df["Unnamed: 5"] = df["Unnamed: 5"].astype(float)
df['Field Value'] = pd.to_datetime(df['Field Value'])
df_grouped = df.groupby([df['Field Value'].dt.year, df['Field Value'].dt.month]).sum()
# df_grouped.reset_index(inplace=True)
# df_grouped.index = pd.to_datetime(df_grouped.index.map(lambda x: f"{x[0]}-{x[1]:02}"))
# df_grouped['new_date_format'] = df_grouped['year'].astype(str) + '-' + df_grouped['month'].astype(str).str.zfill(2)
df_grouped.plot(figsize=(16, 4), grid=True)
# df.set_index("Field Value", inplace=True)
# df.plot()
# Out:
# C:\Users\sasso\AppData\Local\Temp\ipykernel_20088\3815235034.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grouped = df.groupby([df['Field Value'].dt.year, df['Field Value'].dt.month]).sum()
# <AxesSubplot: xlabel='Field Value,Field Value'>
