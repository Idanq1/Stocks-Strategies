# %%
from datetime import datetime, timedelta
import pandas_datareader.data as web
import yfinance as yf
import pandas as pd
import numpy as np
import time

# %%
def get_tickers(file=r"Stock names.txt"):
    with open(file) as f:
        tickers = f.read().split("\n")
    return [ticker for ticker in tickers if "." not in ticker]

# %%
def get_all_tickers():
    # Get a list of all available tickers from Yahoo Finance
    all_tickers = web.get_nasdaq_symbols()
    tickers = all_tickers.index.tolist()
    return [str(ticker) for ticker in tickers if str(ticker).isalpha()]
    
    # with open('tickers.txt', 'w') as file:
    #     for ticker in tickers:
    #         file.write(ticker + '\n')
# get_all_tickers()[:10]

# %%
def get_info(tickers_list):
    df = yf.download(tickers_list, period="1y")

    highs = df['High'].max()
    closes = df['Close'].iloc[-1]
    pct_to_52 = ((highs - closes) / highs) * 100
    volume = df["Volume"].iloc[-1]
    date_of_high = df['High'].idxmax()
    
    new_df = pd.DataFrame({'Close': closes, '52wk High': highs, "Percent from 52": pct_to_52, "Volume": volume, "doh": date_of_high})

    return new_df

# %%
s = time.time()
df = get_info(get_all_tickers()[:400])
print(time.time() - s)
cop = df.copy()
# Out:
# [*********************100%***********************]  400 of 400 completed
# 62.71847081184387

# %%
df = df.dropna(subset=['Close'])
vol_thresh = 10000
df = df[df['Volume'] >= vol_thresh]
time_thresh = datetime.now() - timedelta(days=60)
df = df[df["doh"] < time_thresh]
df.sort_values(by='Percent from 52', ascending=True)
# Out:
#            Close    52wk High  Percent from 52     Volume        doh
# AGNCN  25.549999    25.690001         0.544964    15800.0 2023-03-06
# AIO    18.900000    19.110001         1.098906   110500.0 2022-08-15
# ALIT   10.050000    10.185000         1.325481  3521800.0 2023-02-22
# ACWV   98.709999   100.410004         1.693063   559300.0 2022-08-16
# ADME   37.000999    37.700001         1.854115   101400.0 2022-08-16
# ...          ...          ...              ...        ...        ...
# AKAN    0.690000    15.500000        95.548387    98600.0 2022-08-09
# AKLI    1.160000    37.581001        96.913334    41000.0 2022-08-22
# ADTX    0.429000    28.490000        98.494209    71700.0 2022-09-14
# AGFY    2.740000   416.000000        99.341346    53500.0 2022-10-17
# ALLR    3.080000  3276.000000        99.905983   225000.0 2022-08-18
#
# [214 rows x 5 columns]

# %%
def get_info_test(tickers_list):
    df = yf.download(tickers_list, period="1y")

    days_back = 12
    
    _highs = df['High'][:-days_back].max()
    _closes = df['Close'].iloc[-days_back]
    _pct_to_52 = ((_highs - _closes) / _highs) * 100
    _volume = df["Volume"].iloc[-days_back]
    _date_of_high = df['High'][:-days_back].idxmax()
    
    highs = df['High'].max()
    date_of_high = df['High'].idxmax()
    closes = df['Close'].iloc[-1]
    volume = df["Volume"].iloc[-1]
    pct_to_52 = ((highs - closes) / highs) * 100
    
    new_df = pd.DataFrame({'Old Close': _closes, 'Old 52wk High': _highs, "Old Percent from 52": _pct_to_52, "Old Volume": volume, "doh": _date_of_high, "Close": closes, "Prct252": pct_to_52, "high52": highs, "date of break": date_of_high})

    return new_df

# %%
s = time.time()
df = get_info_test(get_all_tickers()[:3000])
print(time.time() - s)
cop = df.copy()
# Out:
# [*********************100%***********************]  3000 of 3000 completed
#
# 24 Failed downloads:
# - CSLMR: Period '1y' is invalid, must be one of ['1d', '5d']
# - BLACR: Period '1y' is invalid, must be one of ['1d', '5d']
# - BREZR: Period '1y' is invalid, must be one of ['1d', '5d']
# - CBX: Period '1y' is invalid, must be one of ['1d', '5d']
# - ASCBR: Period '1y' is invalid, must be one of ['1d', '5d']
# - BRLIR: Period '1y' is invalid, must be one of ['1d', '5d']
# - ADOCR: Period '1y' is invalid, must be one of ['1d', '5d']
# - CLRCR: Period '1y' is invalid, must be one of ['1d', '5d']
# - DMAQR: Period '1y' is invalid, must be one of ['1d', '5d']
# - ARIZR: Period '1y' is invalid, must be one of ['1d', '5d']
# - ATEST: Period '1y' is invalid, must be one of ['1d', '5d']
# - ASCAR: Period '1y' is invalid, must be one of ['1d', '5d']
# - BLEUR: Period '1y' is invalid, must be one of ['1d', '5d']
# - AQUNR: Period '1y' is invalid, must be one of ['1d', '5d']
# - AIBBR: Period '1y' is invalid, must be one of ['1d', '5d']
# - ALSAR: Period '1y' is invalid, must be one of ['1d', '5d']
# - EAI: No data found for this date range, symbol may be delisted
# - BRACR: Period '1y' is invalid, must be one of ['1d', '5d']
# - BWAQR: Period '1y' is invalid, must be one of ['1d', '5d']
# - CBO: Period '1y' is invalid, must be one of ['1d', '5d']
# - BNIXR: Period '1y' is invalid, must be one of ['1d', '5d']
# - ATMCR: Period '1y' is invalid, must be one of ['1d', '5d']
# - ATAKR: Period '1y' is invalid, must be one of ['1d', '5d']
# - EMCGR: Period '1y' is invalid, must be one of ['1d', '5d']
# 212.2767207622528

# %%
df = cop.copy()
time_thresh = datetime.now() - timedelta(days=120)
break_time_thresh = datetime.now() - timedelta(days=7)  # How many days ago it broke
vol_thresh = 10000

df = df[df["Old 52wk High"] != df["high52"]]
df = df[df['Old Volume'] >= vol_thresh]
df = df[df["doh"] < time_thresh]
df = df[df["date of break"] < break_time_thresh]
df["diff"] = datetime.now() - df["date of break"]
df
# Out:
#         Old Close  Old 52wk High  Old Percent from 52  Old Volume        doh  \
# ABG    236.630005     253.669998             6.717386    286100.0 2023-02-02
# ABOS     5.050000      10.970000            53.965359    779500.0 2022-09-30
# AGNCM   22.450001      22.840000             1.707528     20700.0 2023-02-08
# AIT    142.350006     149.419998             4.731624    129300.0 2023-02-02
# ALGN   330.920013     368.869995            10.288173   1568900.0 2023-02-02
# ALKT    15.740000      17.709999            11.123656    215800.0 2023-02-02
# AMAO    10.300000      10.740000             4.096830    301900.0 2023-03-22
# ARKF    20.590000      21.730000             5.246201    412100.0 2022-08-11
# AUR      2.765000       3.270000            15.443421  12907200.0 2022-08-11
# BETZ    16.999001      17.730000             4.122950     19900.0 2022-08-16
# BITQ     8.780000      10.230000            14.173997    174200.0 2022-08-11
# BKCH    33.360001      37.599998            11.276591     79700.0 2022-08-11
# BKI     58.849998      68.779999            14.437337   3612300.0 2022-08-18
# BLOK    23.459999      25.280001             7.199373    137200.0 2022-08-15
# BRLI    11.230000      11.400000             1.491229     92200.0 2023-03-20
# BWA     44.889999      45.017605             0.283457   1869500.0 2023-03-03
# CBD      4.050000       4.430000             8.577870   1043300.0 2022-11-01
# CLSK     5.390000       6.840000            21.198834   9189700.0 2022-08-11
# DAPP     7.420000       8.390000            11.561385    130400.0 2022-08-15
# DFAE    23.180000      24.360001             4.844008   2059900.0 2023-01-26
# DGHI     1.830000       2.234000            18.084151    208200.0 2023-01-30
# DLB     85.309998      88.059998             3.122871    209100.0 2023-02-03
# EA     130.699997     135.850006             3.790952   4562700.0 2022-08-26
# EGP    174.809998     180.250000             3.018032    238900.0 2022-08-16
# EH      16.150000      17.840000             9.473097    433200.0 2023-01-13
# ELVA     5.000000       5.050000             0.990103     91300.0 2022-09-12
#
#             Close    Prct252      high52 date of break                    diff
# ABG    232.369995   9.368547  256.390015    2023-07-11 13 days 00:12:13.435096
# ABOS     7.400000  34.571178   11.310000    2023-07-17  7 days 00:12:13.435096
# AGNCM   22.400000   1.969369   22.850000    2023-07-17  7 days 00:12:13.435096
# AIT    143.339996   4.484581  150.070007    2023-07-12 12 days 00:12:13.435096
# ALGN   337.369995   9.306701  371.989990    2023-07-17  7 days 00:12:13.435096
# ALKT    16.330000   7.844241   17.719999    2023-07-13 11 days 00:12:13.435096
# AMAO    10.925000   2.715934   11.230000    2023-07-14 10 days 00:12:13.435096
# ARKF    23.070000   4.708796   24.209999    2023-07-14 10 days 00:12:13.435096
# AUR      2.720000  23.163840    3.540000    2023-07-12 12 days 00:12:13.435096
# BETZ    18.535000   1.983078   18.910000    2023-07-14 10 days 00:12:13.435096
# BITQ    10.020000  11.624623   11.338000    2023-07-14 10 days 00:12:13.435096
# BKCH    37.770000  14.159090   44.000000    2023-07-14 10 days 00:12:13.435096
# BKI     70.309998   1.650581   71.489998    2023-07-17  7 days 00:12:13.435096
# BLOK    25.629999   6.442786   27.395000    2023-07-14 10 days 00:12:13.435096
# BRLI    11.570000  24.772434   15.380000    2023-07-14 10 days 00:12:13.435096
# BWA     46.139999   1.934112   47.049999    2023-07-13 11 days 00:12:13.435096
# CBD      4.560000   4.201686    4.760000    2023-07-12 12 days 00:12:13.435096
# CLSK     6.420000  15.515198    7.599000    2023-07-17  7 days 00:12:13.435096
# DAPP     8.500000  12.909838    9.760000    2023-07-14 10 days 00:12:13.435096
# DFAE    23.980000   1.761574   24.410000    2023-07-13 11 days 00:12:13.435096
# DGHI     1.940000  23.622044    2.540000    2023-07-14 10 days 00:12:13.435096
# DLB     88.800003   2.439017   91.019997    2023-07-13 11 days 00:12:13.435096
# EA     137.059998   2.309341  140.300003    2023-07-17  7 days 00:12:13.435096
# EGP    184.759995   0.821299  186.289993    2023-07-17  7 days 00:12:13.435096
# EH      17.120001  13.796574   19.860001    2023-07-12 12 days 00:12:13.435096
# ELVA     5.270000   4.181819    5.500000    2023-07-07 17 days 00:12:13.435096
