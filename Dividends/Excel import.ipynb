# %%
import pandas as pd
df = pd.read_excel(r"עותק של U.S.DividendChampions-LIVE.xlsx", sheet_name="All", skiprows=1, index_col=0, skipfooter=1)
df.sort_values("Div Yield", ascending=False)
# Out:
#                                         Company  FV       Sector  No Years  \
# Symbol
# CSWC              Capital Southwest Corporation NaN   Financials       7.0
# ACRE    Ares Commercial Real Estate Corporation NaN   Financials       7.0
# ABR                    Arbor Realty Trust, Inc. NaN   Financials      10.0
# HTGC                     Hercules Capital, Inc. NaN   Financials       5.0
# AQN           Algonquin Power & Utilities Corp. NaN    Utilities      11.0
# ...                                         ...  ..          ...       ...
# BCC                       Boise Cascade Company NaN    Materials       5.0
# RLI                                   RLI Corp. NaN   Financials      47.0
# KNSL                Kinsale Capital Group, Inc. NaN   Financials       6.0
# HEI.A                         HEICO Corporation NaN  Industrials      18.0
# HEI                           HEICO Corporation NaN  Industrials      17.0
#
# ...
